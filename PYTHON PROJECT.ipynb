# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\Dell\Downloads\8. Netflix Dataset.csv')

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# # TASK 1

# %%
# IS THERE ANY DUPLICATE RECORD IN THE DATASET? IF YES THEN REMOVE THE DUPLICATE RECORDS

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# # TASK 2

# %%
# IS THERE ANY NULL VALUE PRESENT IN ANY COLUMN? SHOW WITH THE HEATMAP.

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # TASK 3

# %%
# FOR "ZUBAN" , WHAT IS THE SHOWID AND WHO IS THE DIRECTOR OF THHIS SHOW?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # TASK 4

# %%
# IN WHICH YEAR HIGHEST NUMBER OF TV SHOWS AND MOVIES WERE RELEASED? SHOW WITH BAR GRAPH.

# %%
data['Date_N']=pd.to_datetime(data['Release_Date'])

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # TASK 5

# %%
# HOW MANY TV SHOWS AND MOVIES ARE THERE IN THE DATASET? SHOW WITH THE BARGRAPH

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
data.groupby('Category').Category.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# # TASK 6

# %%
# SHOW ALL THE MOVIES THAT WERE RELAESED IN YEAR 2010

# %%
data['Year']=data['Date_N'].dt.year

# %%
data[(data['Category']=='Movie')&(data['Year']==2010)]
# Out:
#      Show_Id Category                        Title    Director  \
# 3840   s3841    Movie  Mad Ron's Prevues from Hell  Jim Monaco
#
#                                                    Cast        Country  \
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
#
#           Release_Date Rating Duration                        Type  \
# 3840  November 1, 2010     NR   84 min  Cult Movies, Horror Movies
#
#                                             Description     Date_N    Year
# 3840  This collection cherry-picks trailers, forgott... 2010-11-01  2010.0

# %% [markdown]
# # TASK 7

# %%
# SHOW TOP10 DIRECTORS , WHO GAVE THE HIGHEST NUMBER OF TV SHOWS & MOVIES TO NETFLIX

# %%
data['Director'].value_counts()
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
#                           ..
# Vibhu Virender Puri        1
# Lucien Jean-Baptiste       1
# Jason Krawczyk             1
# Quinn Lasher               1
# Sam Dunn                   1
# Name: Director, Length: 4050, dtype: int64

# %%
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# # TASK 8

# %%
# SHOW ALL THE RECORDS WHERE 'CATEGORY' IS 'MOVIES' AND TYPE IS 'COMIDIES' OR COUNTRY IS 'UNITED KINGDOM'

# %%
data[(data['Category']=='Movie')&((data['Type']=='Comidies')|(data['Country']=='United Kingdom'))]
# Out:
#      Show_Id Category                       Title  \
# 7615   s7614    Movie  Why Are We Getting So Fat?
# 7628   s7627    Movie                    Williams
# 7649   s7648    Movie               Without Gorky
# 7688   s7687    Movie      XV: Beyond the Tryline
# 7725   s7724    Movie                You Can Tutu
#
#                                     Director  \
# 7615  Milla Harrison-Hansley, Alicky Sussman
# 7628                         Morgan Matthews
# 7649                          Cosima Spender
# 7688                        Pierre Deschamps
# 7725                             James Brown
#
#                                                    Cast         Country  \
# 7615                                          Giles Yeo  United Kingdom
# 7628                                                NaN  United Kingdom
# 7649                                                NaN  United Kingdom
# 7688                                                NaN  United Kingdom
# ...

# %% [markdown]
# # TASK 9

# %%
# IN HOW MANY MOVIES/SHOWS 'TOM CRUISE' WAS CAST?

# %%
# data[data['Cast'].str.contains("Tom Cruise")] .. shows error as cast column contains null

# %%
data_new=data.dropna()

# %%
data_new.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# # TASK 10

# %%
# WHAT ARE THE DIFFERENT RATINGS DEFINED BY NETFLIX?

# %%
data.groupby('Rating')['Rating'].count()
# Out:
# Rating
# G             39
# NC-17          3
# NR            84
# PG           247
# PG-13        386
# R            665
# TV-14       1931
# TV-G         194
# TV-MA       2863
# TV-PG        806
# TV-Y         280
# TV-Y7        271
# TV-Y7-FV       6
# UR             5
# Name: Rating, dtype: int64

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
data['Rating'].nunique()
# Out:
# 14

# %%
data['Rating'].value_counts()
# Out:
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: Rating, dtype: int64

# %% [markdown]
# # TASK 11

# %%
# HOW MANY MOVIE GOT THE 'TV-14' RATING, IN CANADA?

# %%
data[(data['Category']=='Movie')&(data['Rating']=='TV-14')&(data['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
data[(data['Category']=='Movie')&(data['Rating']=='TV-14')&(data['Country']=='Canada')].shape
# Out:
# (11, 13)

# %% [markdown]
# # TASK 12

# %%
# WHICH INDIVIDUAL COUNTRY HAS THR HIGHEST NUMBER OF TV SHOWS?

# %%
data_new_show=data[data['Category']=='TV Show']

# %%
data_new_show['Country'].value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %%
data_new_show['Country'].value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# # TASK 13

# %%
# HOW CAN WE SORT THE DATASET BY YEAR?

# %%
data.sort_values(by='Year',ascending=False)
# Out:
#      Show_Id Category                         Title                 Director  \
# 5564   s5564    Movie               Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie                     Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show                  Bling Empire                      NaN
# 5955   s5955    Movie              Taare Zameen Par               Aamir Khan
# 366     s367    Movie                     Al acecho      Francisco D'Eufemia
# ...      ...      ...                           ...                      ...
# 3374   s3375  TV Show                      Kikoriki                      NaN
# 3492   s3493  TV Show           La Familia P. Luche                      NaN
# 3946   s3947  TV Show                         Maron                      NaN
# 5138   s5138  TV Show                  Red vs. Blue                      NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                      NaN
#
# ...
